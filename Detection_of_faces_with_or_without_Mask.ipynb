# %% [markdown]
# ## **Problem Statement**
# The dataset consists of 1376 images consisting of two classes – with_mask and without_mask. The objective to create a Face Mask Detector using CNN and OpenCV.
#
# **TASKS:**
# * Prepare a detailed python notebook using CNN for detecting Face Masks in Real-time
# * Import Required Libraries
# * Load and Pre-process the dataset
# * Visualize the dataset
# * Design a Convolutional Neural Network (CNN) Model
# * Compile the Model
# * Train the Model
# * Evaluate the Model
# * Detect the Face Masks using the HaarCascade_frontalface_default.xml file in real time
#
# **DATASET**
# https://drive.google.com/drive/folders/1cB1Eai6UxqmqbONCT99hpoPAGRgvzxpp

# %% [markdown]
# ## **Loading dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-df2aa124-fdd6-40a0-847a-8208f8d6c286" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df2aa124-fdd6-40a0-847a-8208f8d6c286">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset-20200804T034900Z-001.zip to dataset-20200804T034900Z-001.zip

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#   inflating: dataset/without_mask/augmented_image_83.jpg
#   inflating: dataset/without_mask/augmented_image_87.jpg
#   inflating: dataset/without_mask/augmented_image_92.jpg
#   inflating: dataset/without_mask/augmented_image_52.jpg
#   inflating: dataset/without_mask/augmented_image_94.jpg
#   inflating: dataset/without_mask/augmented_image_85.jpg
#   inflating: dataset/without_mask/augmented_image_88.jpg
#   inflating: dataset/without_mask/augmented_image_79.jpg
#   inflating: dataset/without_mask/augmented_image_82.jpg
#   inflating: dataset/without_mask/augmented_image_95.jpg
#   inflating: dataset/without_mask/augmented_image_84.jpg
#   inflating: dataset/without_mask/augmented_image_86.jpg
#   inflating: dataset/without_mask/augmented_image_93.jpg
#   inflating: dataset/without_mask/augmented_image_81.jpg
#   inflating: dataset/without_mask/augmented_image_77.jpg
#   inflating: dataset/without_mask/augmented_image_99.jpg
#   inflating: dataset/without_mask/augmented_image_59.jpg
#   inflating: dataset/without_mask/augmented_image_90.jpg
#   inflating: dataset/without_mask/augmented_image_96.jpg
#   inflating: dataset/without_mask/augmented_image_89.jpg
#   inflating: dataset/without_mask/augmented_image_97.jpg
#   inflating: dataset/without_mask/augmented_image_98.jpg
#   inflating: dataset/without_mask/augmented_image_91.jpg
#   inflating: dataset/with_mask/augmented_image_83.jpg
#   inflating: dataset/without_mask/augmented_image_80.jpg
#   inflating: dataset/with_mask/augmented_image_87.jpg
#   inflating: dataset/with_mask/augmented_image_9.jpg
#   inflating: dataset/with_mask/augmented_image_81.jpg
#   inflating: dataset/with_mask/augmented_image_69.jpg
#   inflating: dataset/without_mask/augmented_image_78.jpg
#   inflating: dataset/with_mask/augmented_image_86.jpg
#   inflating: dataset/with_mask/augmented_image_84.jpg
#   inflating: dataset/with_mask/augmented_image_92.jpg
#   inflating: dataset/with_mask/augmented_image_74.jpg
#   inflating: dataset/with_mask/augmented_image_80.jpg
#   inflating: dataset/with_mask/augmented_image_76.jpg
#   inflating: dataset/with_mask/prajna.jpg
#   inflating: dataset/with_mask/augmented_image_99.jpg
#   inflating: dataset/with_mask/augmented_image_91.jpg
#   inflating: dataset/with_mask/augmented_image_85.jpg
#   inflating: dataset/with_mask/pra2.jpg
#   inflating: dataset/with_mask/augmented_image_96.jpg
#   inflating: dataset/with_mask/augmented_image_78.jpg
#   inflating: dataset/with_mask/augmented_image_77.jpg
#   inflating: dataset/with_mask/augmented_image_97.jpg
#   inflating: dataset/with_mask/augmented_image_90.jpg
#   inflating: dataset/with_mask/augmented_image_79.jpg
#   inflating: dataset/with_mask/augmented_image_8.jpg
#   inflating: dataset/with_mask/pra1.jpg
#   inflating: dataset/with_mask/augmented_image_98.jpg
#   inflating: dataset/with_mask/pra3.jpg
#   inflating: dataset/with_mask/augmented_image_93.jpg
#   inflating: dataset/with_mask/augmented_image_72.jpg
#   inflating: dataset/with_mask/augmented_image_73.jpg
#   inflating: dataset/with_mask/augmented_image_75.jpg
#   inflating: dataset/with_mask/augmented_image_58.jpg
#   inflating: dataset/with_mask/augmented_image_82.jpg
#   inflating: dataset/with_mask/augmented_image_71.jpg
#   inflating: dataset/with_mask/augmented_image_40.jpg
#   inflating: dataset/with_mask/augmented_image_7.jpg
#   inflating: dataset/with_mask/augmented_image_44.jpg
#   inflating: dataset/with_mask/augmented_image_38.jpg
#   inflating: dataset/with_mask/augmented_image_88.jpg
#   inflating: dataset/with_mask/augmented_image_49.jpg
#   inflating: dataset/with_mask/augmented_image_48.jpg
#   inflating: dataset/with_mask/augmented_image_6.jpg
#   inflating: dataset/with_mask/augmented_image_94.jpg
#   inflating: dataset/with_mask/augmented_image_4.jpg
#   inflating: dataset/with_mask/augmented_image_89.jpg
#   inflating: dataset/with_mask/augmented_image_63.jpg
#   inflating: dataset/with_mask/augmented_image_59.jpg
#   inflating: dataset/with_mask/augmented_image_68.jpg
#   inflating: dataset/with_mask/augmented_image_45.jpg
#   inflating: dataset/with_mask/augmented_image_62.jpg
#   inflating: dataset/with_mask/augmented_image_42.jpg
#   inflating: dataset/with_mask/augmented_image_70.jpg
#   inflating: dataset/with_mask/augmented_image_41.jpg
#   inflating: dataset/with_mask/augmented_image_46.jpg
#   inflating: dataset/with_mask/augmented_image_66.jpg
#   inflating: dataset/with_mask/augmented_image_5.jpg
#   inflating: dataset/with_mask/augmented_image_43.jpg
#   inflating: dataset/with_mask/augmented_image_67.jpg
#   inflating: dataset/with_mask/augmented_image_56.jpg
#   inflating: dataset/with_mask/augmented_image_61.jpg
#   inflating: dataset/with_mask/augmented_image_57.jpg
#   inflating: dataset/with_mask/augmented_image_303.jpg
#   inflating: dataset/with_mask/augmented_image_39.jpg
#   inflating: dataset/with_mask/augmented_image_65.jpg
#   inflating: dataset/with_mask/augmented_image_55.jpg
#   inflating: dataset/with_mask/augmented_image_54.jpg
#   inflating: dataset/with_mask/augmented_image_53.jpg
#   inflating: dataset/with_mask/augmented_image_50.jpg
#   inflating: dataset/with_mask/augmented_image_52.jpg
#   inflating: dataset/with_mask/augmented_image_35.jpg
#   inflating: dataset/with_mask/augmented_image_29.jpg
#   inflating: dataset/with_mask/augmented_image_31.jpg
#   inflating: dataset/with_mask/augmented_image_36.jpg
#   inflating: dataset/with_mask/augmented_image_64.jpg
#   inflating: dataset/with_mask/augmented_image_284.jpg
#   inflating: dataset/with_mask/augmented_image_310.jpg
#   inflating: dataset/with_mask/augmented_image_51.jpg
#   inflating: dataset/with_mask/augmented_image_47.jpg
#   inflating: dataset/with_mask/augmented_image_291.jpg
#   inflating: dataset/with_mask/augmented_image_315.jpg
#   inflating: dataset/with_mask/augmented_image_306.jpg
#   inflating: dataset/with_mask/augmented_image_60.jpg
#   inflating: dataset/with_mask/augmented_image_285.jpg
#   inflating: dataset/with_mask/augmented_image_37.jpg
#   inflating: dataset/with_mask/augmented_image_3.jpg
#   inflating: dataset/with_mask/augmented_image_33.jpg
#   inflating: dataset/with_mask/augmented_image_311.jpg
#   inflating: dataset/with_mask/augmented_image_308.jpg
#   inflating: dataset/with_mask/augmented_image_238.jpg
#   inflating: dataset/without_mask/augmented_image_17.jpg
#   inflating: dataset/with_mask/augmented_image_173.jpg
#   inflating: dataset/with_mask/augmented_image_172.jpg
#   inflating: dataset/with_mask/augmented_image_19.jpg
#   inflating: dataset/with_mask/augmented_image_314.jpg
#   inflating: dataset/without_mask/augmented_image_223.jpg
#   inflating: dataset/without_mask/augmented_image_165.jpg
#   inflating: dataset/without_mask/49.jpg
#   inflating: dataset/without_mask/441.jpg
#   inflating: dataset/with_mask/augmented_image_262.jpg
#   inflating: dataset/with_mask/augmented_image_266.jpg
#   inflating: dataset/without_mask/augmented_image_250.jpg
#   inflating: dataset/without_mask/40.jpg
#   inflating: dataset/without_mask/augmented_image_267.jpg
#   inflating: dataset/without_mask/augmented_image_152.jpg
#   inflating: dataset/without_mask/augmented_image_21.jpg
#   inflating: dataset/with_mask/augmented_image_286.jpg
#   inflating: dataset/without_mask/augmented_image_294.jpg
#   inflating: dataset/without_mask/augmented_image_151.jpg
#   inflating: dataset/with_mask/409-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_66.jpg
#   inflating: dataset/without_mask/augmented_image_295.jpg
#   inflating: dataset/without_mask/augmented_image_140.jpg
#   inflating: dataset/without_mask/augmented_image_51.jpg
#   inflating: dataset/without_mask/438.jpg
#   inflating: dataset/without_mask/9.jpg
#   inflating: dataset/without_mask/augmented_image_43.jpg
#   inflating: dataset/without_mask/252.jpg
#   inflating: dataset/without_mask/240.jpg
#   inflating: dataset/with_mask/augmented_image_198.jpg
#   inflating: dataset/without_mask/254.jpg
#   inflating: dataset/with_mask/402-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_230.jpg
#   inflating: dataset/without_mask/192.jpg
#   inflating: dataset/with_mask/274-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_282.jpg
#   inflating: dataset/with_mask/179-with-mask.jpg
#   inflating: dataset/without_mask/332.jpg
#   inflating: dataset/without_mask/292.jpg
#   inflating: dataset/with_mask/394-with-mask.jpg
#   inflating: dataset/with_mask/49-with-mask.jpg
#   inflating: dataset/without_mask/335.jpg
#   inflating: dataset/with_mask/augmented_image_246.jpg
#   inflating: dataset/without_mask/augmented_image_233.jpg
#   inflating: dataset/without_mask/11.jpg
#   inflating: dataset/without_mask/158.jpg
#   inflating: dataset/with_mask/augmented_image_264.jpg
#   inflating: dataset/with_mask/51-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_197.jpg
#   inflating: dataset/with_mask/13-with-mask.jpg
#   inflating: dataset/with_mask/168-with-mask.jpg
#   inflating: dataset/with_mask/56-with-mask.jpg
#   inflating: dataset/without_mask/193.jpg
#   inflating: dataset/with_mask/augmented_image_168.jpg
#   inflating: dataset/with_mask/273-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_216.jpg
#   inflating: dataset/without_mask/augmented_image_125.jpg
#   inflating: dataset/without_mask/341.jpg
#   inflating: dataset/without_mask/249.jpg
#   inflating: dataset/without_mask/109.jpg
#   inflating: dataset/without_mask/augmented_image_70.jpg
#   inflating: dataset/with_mask/309-with-mask.jpg
#   inflating: dataset/without_mask/250.jpg
#   inflating: dataset/without_mask/17.jpg
#   inflating: dataset/without_mask/augmented_image_147.jpg
#   inflating: dataset/with_mask/6-with-mask.jpg
#   inflating: dataset/with_mask/239-with-mask.jpg
#   inflating: dataset/without_mask/428.jpg
#   inflating: dataset/with_mask/augmented_image_154.jpg
#   inflating: dataset/with_mask/343-with-mask.jpg
#   inflating: dataset/without_mask/62.jpg
#   inflating: dataset/without_mask/augmented_image_301.jpg
#   inflating: dataset/without_mask/186.jpg
#   inflating: dataset/without_mask/444.jpg
#   inflating: dataset/with_mask/92-with-mask.jpg
#   inflating: dataset/without_mask/33.jpg
#   inflating: dataset/with_mask/augmented_image_280.jpg
#   inflating: dataset/without_mask/283.jpg
#   inflating: dataset/without_mask/59.jpg
#   inflating: dataset/with_mask/augmented_image_212.jpg
#   inflating: dataset/without_mask/augmented_image_214.jpg
#   inflating: dataset/with_mask/113-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_127.jpg
#   inflating: dataset/without_mask/322.jpg
#   inflating: dataset/without_mask/295.jpg
#   inflating: dataset/with_mask/augmented_image_129.jpg
#   inflating: dataset/with_mask/132-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_288.jpg
#   inflating: dataset/with_mask/305-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_215.jpg
#   inflating: dataset/with_mask/415-with-mask.jpg
#   inflating: dataset/without_mask/467.jpg
#   inflating: dataset/with_mask/augmented_image_177.jpg
#   inflating: dataset/with_mask/365-with-mask.jpg
#   inflating: dataset/with_mask/413-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_0.jpg
#   inflating: dataset/without_mask/augmented_image_123.jpg
#   inflating: dataset/with_mask/345-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_176.jpg
#   inflating: dataset/with_mask/383-with-mask.jpg
#   inflating: dataset/with_mask/460-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_188.jpg
#   inflating: dataset/without_mask/439.jpg
#   inflating: dataset/without_mask/augmented_image_253.jpg
#   inflating: dataset/without_mask/315.jpg
#   inflating: dataset/without_mask/361.jpg
#   inflating: dataset/without_mask/436.jpg
#   inflating: dataset/with_mask/augmented_image_114.jpg
#   inflating: dataset/with_mask/405-with-mask.jpg
#   inflating: dataset/with_mask/366-with-mask.jpg
#   inflating: dataset/without_mask/431.jpg
#   inflating: dataset/with_mask/430-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_160.jpg
#   inflating: dataset/without_mask/69.jpg
#   inflating: dataset/without_mask/augmented_image_196.jpg
#   inflating: dataset/without_mask/206.jpg
#   inflating: dataset/with_mask/115-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_100.jpg
#   inflating: dataset/without_mask/augmented_image_163.jpg
#   inflating: dataset/with_mask/326-with-mask.jpg
#   inflating: dataset/without_mask/53.jpg
#   inflating: dataset/without_mask/augmented_image_130.jpg
#   inflating: dataset/without_mask/216.jpg
#   inflating: dataset/without_mask/469.jpg
#   inflating: dataset/without_mask/augmented_image_269.jpg
#   inflating: dataset/with_mask/122-with-mask.jpg
#   inflating: dataset/without_mask/359.jpg
#   inflating: dataset/without_mask/augmented_image_238.jpg
#   inflating: dataset/without_mask/augmented_image_285.jpg
#   inflating: dataset/with_mask/augmented_image_118.jpg
#   inflating: dataset/without_mask/197.jpg
#   inflating: dataset/with_mask/augmented_image_14.jpg
#   inflating: dataset/with_mask/augmented_image_101.jpg
#   inflating: dataset/with_mask/148-with-mask.jpg
#   inflating: dataset/with_mask/157-with-mask.jpg
#   inflating: dataset/with_mask/42-with-mask.jpg
#   inflating: dataset/with_mask/186-with-mask.jpg
#   inflating: dataset/without_mask/185.jpg
#   inflating: dataset/with_mask/224-with-mask.jpg
#   inflating: dataset/without_mask/133.jpg
#   inflating: dataset/without_mask/400.jpg
#   inflating: dataset/without_mask/augmented_image_101.jpg
#   inflating: dataset/without_mask/267.jpg
#   inflating: dataset/without_mask/26.jpg
#   inflating: dataset/with_mask/435-with-mask.jpg
#   inflating: dataset/without_mask/96.jpg
#   inflating: dataset/with_mask/479-with-mask.jpg
#   inflating: dataset/with_mask/387-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_55.jpg
#   inflating: dataset/with_mask/augmented_image_17.jpg
#   inflating: dataset/with_mask/augmented_image_134.jpg
#   inflating: dataset/with_mask/344-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_33.jpg
#   inflating: dataset/with_mask/434-with-mask.jpg
#   inflating: dataset/with_mask/165-with-mask.jpg
#   inflating: dataset/without_mask/282.jpg
#   inflating: dataset/with_mask/74-with-mask.jpg
#   inflating: dataset/without_mask/328.jpg
#   inflating: dataset/without_mask/183.jpg
#   inflating: dataset/with_mask/61-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_22.jpg
#   inflating: dataset/with_mask/288-with-mask.jpg
#   inflating: dataset/with_mask/315-with-mask.jpg
#   inflating: dataset/with_mask/195-with-mask.jpg
#   inflating: dataset/without_mask/43.jpg
#   inflating: dataset/without_mask/411.jpg
#   inflating: dataset/without_mask/augmented_image_266.jpg
#   inflating: dataset/without_mask/221.jpg
#   inflating: dataset/without_mask/augmented_image_175.jpg
#   inflating: dataset/with_mask/359-with-mask.jpg
#   inflating: dataset/without_mask/157.jpg
#   inflating: dataset/with_mask/augmented_image_11.jpg
#   inflating: dataset/without_mask/276.jpg
#   inflating: dataset/with_mask/augmented_image_257.jpg
#   inflating: dataset/without_mask/augmented_image_166.jpg
#   inflating: dataset/without_mask/45.jpg
#   inflating: dataset/with_mask/302-with-mask.jpg
#   inflating: dataset/with_mask/261-with-mask.jpg
#   inflating: dataset/with_mask/299-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_200.jpg
#   inflating: dataset/without_mask/augmented_image_4.jpg
#   inflating: dataset/with_mask/183-with-mask.jpg
#   inflating: dataset/without_mask/174.jpg
#   inflating: dataset/with_mask/47-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_204.jpg
#   inflating: dataset/with_mask/212-with-mask.jpg
#   inflating: dataset/with_mask/242-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_178.jpg
#   inflating: dataset/with_mask/augmented_image_34.jpg
#   inflating: dataset/with_mask/augmented_image_15.jpg
#   inflating: dataset/with_mask/augmented_image_237.jpg
#   inflating: dataset/without_mask/73.jpg
#   inflating: dataset/without_mask/448.jpg
#   inflating: dataset/with_mask/augmented_image_188.jpg
#   inflating: dataset/without_mask/393.jpg
#   inflating: dataset/with_mask/augmented_image_10.jpg
#   inflating: dataset/without_mask/augmented_image_244.jpg
#   inflating: dataset/with_mask/119-with-mask.jpg
#   inflating: dataset/without_mask/434.jpg
#   inflating: dataset/without_mask/augmented_image_317.jpg
#   inflating: dataset/with_mask/284-with-mask.jpg
#   inflating: dataset/with_mask/173-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_171.jpg
#   inflating: dataset/without_mask/54.jpg
#   inflating: dataset/without_mask/477.jpg
#   inflating: dataset/without_mask/248.jpg
#   inflating: dataset/with_mask/83-with-mask.jpg
#   inflating: dataset/without_mask/143.jpg
#   inflating: dataset/with_mask/323-with-mask.jpg
#   inflating: dataset/with_mask/138-with-mask.jpg
#   inflating: dataset/without_mask/138.jpg
#   inflating: dataset/with_mask/392-with-mask.jpg
#   inflating: dataset/without_mask/105.jpg
#   inflating: dataset/with_mask/augmented_image_316.jpg
#   inflating: dataset/without_mask/36.jpg
#   inflating: dataset/without_mask/augmented_image_181.jpg
#   inflating: dataset/without_mask/augmented_image_1.jpg
#   inflating: dataset/with_mask/427-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_243.jpg
#   inflating: dataset/without_mask/208.jpg
#   inflating: dataset/without_mask/augmented_image_149.jpg
#   inflating: dataset/without_mask/55.jpg
#   inflating: dataset/with_mask/80-with-mask.jpg
#   inflating: dataset/with_mask/464-with-mask.jpg
#   inflating: dataset/without_mask/152.jpg
#   inflating: dataset/with_mask/augmented_image_121.jpg
#   inflating: dataset/without_mask/augmented_image_319.jpg
#   inflating: dataset/with_mask/augmented_image_155.jpg
#   inflating: dataset/without_mask/10.jpg
#   inflating: dataset/with_mask/207-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_296.jpg
#   inflating: dataset/with_mask/407-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_105.jpg
#   inflating: dataset/without_mask/81.jpg
#   inflating: dataset/without_mask/augmented_image_137.jpg
#   inflating: dataset/with_mask/augmented_image_183.jpg
#   inflating: dataset/with_mask/463-with-mask.jpg
#   inflating: dataset/with_mask/420-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_24.jpg
#   inflating: dataset/without_mask/239.jpg
#   inflating: dataset/with_mask/augmented_image_217.jpg
#   inflating: dataset/with_mask/118-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_208.jpg
#   inflating: dataset/with_mask/augmented_image_106.jpg
#   inflating: dataset/without_mask/160.jpg
#   inflating: dataset/without_mask/102.jpg
#   inflating: dataset/with_mask/135-with-mask.jpg
#   inflating: dataset/without_mask/88.jpg
#   inflating: dataset/without_mask/104.jpg
#   inflating: dataset/with_mask/228-with-mask.jpg
#   inflating: dataset/with_mask/211-with-mask.jpg
#   inflating: dataset/with_mask/91-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_179.jpg
#   inflating: dataset/without_mask/augmented_image_111.jpg
#   inflating: dataset/with_mask/416-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_135.jpg
#   inflating: dataset/with_mask/311-with-mask.jpg
#   inflating: dataset/without_mask/77.jpg
#   inflating: dataset/without_mask/augmented_image_164.jpg
#   inflating: dataset/without_mask/2.jpg
#   inflating: dataset/without_mask/29.jpg
#   inflating: dataset/with_mask/9-with-mask.jpg
#   inflating: dataset/without_mask/417.jpg
#   inflating: dataset/with_mask/augmented_image_116.jpg
#   inflating: dataset/with_mask/454-with-mask.jpg
#   inflating: dataset/without_mask/170.jpg
#   inflating: dataset/without_mask/408.jpg
#   inflating: dataset/without_mask/339.jpg
#   inflating: dataset/with_mask/278-with-mask.jpg
#   inflating: dataset/without_mask/246.jpg
#   inflating: dataset/without_mask/175.jpg
#   inflating: dataset/with_mask/augmented_image_181.jpg
#   inflating: dataset/with_mask/augmented_image_265.jpg
#   inflating: dataset/with_mask/225-with-mask.jpg
#   inflating: dataset/without_mask/114.jpg
#   inflating: dataset/with_mask/398-with-mask.jpg
#   inflating: dataset/with_mask/393-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_38.jpg
#   inflating: dataset/with_mask/25-with-mask.jpg
#   inflating: dataset/without_mask/90.jpg
#   inflating: dataset/with_mask/augmented_image_204.jpg
#   inflating: dataset/without_mask/390.jpg
#   inflating: dataset/without_mask/augmented_image_72.jpg
#   inflating: dataset/without_mask/augmented_image_103.jpg
#   inflating: dataset/with_mask/augmented_image_244.jpg
#   inflating: dataset/without_mask/augmented_image_27.jpg
#   inflating: dataset/with_mask/50-with-mask.jpg
#   inflating: dataset/without_mask/463.jpg
#   inflating: dataset/with_mask/augmented_image_185.jpg
#   inflating: dataset/without_mask/augmented_image_158.jpg
#   inflating: dataset/without_mask/260.jpg
#   inflating: dataset/without_mask/augmented_image_279.jpg
#   inflating: dataset/with_mask/475-with-mask.jpg
#   inflating: dataset/without_mask/56.jpg
#   inflating: dataset/with_mask/augmented_image_30.jpg
#   inflating: dataset/without_mask/372.jpg
#   inflating: dataset/without_mask/201.jpg
#   inflating: dataset/with_mask/477-with-mask.jpg
#   inflating: dataset/with_mask/0-with-mask.jpg
#   inflating: dataset/with_mask/226-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_167.jpg
#   inflating: dataset/with_mask/augmented_image_175.jpg
#   inflating: dataset/without_mask/162.jpg
#   inflating: dataset/without_mask/augmented_image_153.jpg
#   inflating: dataset/with_mask/215-with-mask.jpg
#   inflating: dataset/with_mask/120-with-mask.jpg
#   inflating: dataset/with_mask/111-with-mask.jpg
#   inflating: dataset/without_mask/468.jpg
#   inflating: dataset/with_mask/augmented_image_219.jpg
#   inflating: dataset/with_mask/406-with-mask.jpg
#   inflating: dataset/with_mask/129-with-mask.jpg
#   inflating: dataset/with_mask/31-with-mask.jpg
#   inflating: dataset/with_mask/400-with-mask.jpg
#   inflating: dataset/without_mask/232.jpg
#   inflating: dataset/with_mask/126-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_206.jpg
#   inflating: dataset/with_mask/64-with-mask.jpg
#   inflating: dataset/without_mask/115.jpg
#   inflating: dataset/with_mask/457-with-mask.jpg
#   inflating: dataset/without_mask/84.jpg
#   inflating: dataset/without_mask/217.jpg
#   inflating: dataset/without_mask/352.jpg
#   inflating: dataset/with_mask/376-with-mask.jpg
#   inflating: dataset/without_mask/373.jpg
#   inflating: dataset/without_mask/augmented_image_18.jpg
#   inflating: dataset/without_mask/379.jpg
#   inflating: dataset/with_mask/349-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_185.jpg
#   inflating: dataset/with_mask/202-with-mask.jpg
#   inflating: dataset/without_mask/291.jpg
#   inflating: dataset/without_mask/86.jpg
#   inflating: dataset/without_mask/106.jpg
#   inflating: dataset/with_mask/295-with-mask.jpg
#   inflating: dataset/without_mask/406.jpg
#   inflating: dataset/without_mask/247.jpg
#   inflating: dataset/without_mask/308.jpg
#   inflating: dataset/without_mask/augmented_image_162.jpg
#   inflating: dataset/with_mask/16-with-mask.jpg
#   inflating: dataset/without_mask/362.jpg
#   inflating: dataset/without_mask/324.jpg
#   inflating: dataset/with_mask/augmented_image_176.jpg
#   inflating: dataset/without_mask/271.jpg
#   inflating: dataset/with_mask/19-with-mask.jpg
#   inflating: dataset/without_mask/368.jpg
#   inflating: dataset/without_mask/augmented_image_197.jpg
#   inflating: dataset/without_mask/117.jpg
#   inflating: dataset/without_mask/augmented_image_14.jpg
#   inflating: dataset/without_mask/432.jpg
#   inflating: dataset/with_mask/88-with-mask.jpg
#   inflating: dataset/with_mask/150-with-mask.jpg
#   inflating: dataset/with_mask/439-with-mask.jpg
#   inflating: dataset/with_mask/353-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_280.jpg
#   inflating: dataset/without_mask/augmented_image_209.jpg
#   inflating: dataset/with_mask/augmented_image_221.jpg
#   inflating: dataset/without_mask/augmented_image_73.jpg
#   inflating: dataset/with_mask/97-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_151.jpg
#   inflating: dataset/without_mask/augmented_image_61.jpg
#   inflating: dataset/with_mask/327-with-mask.jpg
#   inflating: dataset/with_mask/396-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_232.jpg
#   inflating: dataset/with_mask/128-with-mask.jpg
#   inflating: dataset/with_mask/283-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_193.jpg
#   inflating: dataset/without_mask/augmented_image_225.jpg
#   inflating: dataset/without_mask/336.jpg
#   inflating: dataset/without_mask/367.jpg
#   inflating: dataset/without_mask/363.jpg
#   inflating: dataset/without_mask/augmented_image_189.jpg
#   inflating: dataset/without_mask/augmented_image_142.jpg
#   inflating: dataset/with_mask/104-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_180.jpg
#   inflating: dataset/with_mask/162-with-mask.jpg
#   inflating: dataset/with_mask/2-with-mask.jpg
#   inflating: dataset/without_mask/57.jpg
#   inflating: dataset/without_mask/augmented_image_145.jpg
#   inflating: dataset/without_mask/253.jpg
#   inflating: dataset/without_mask/93.jpg
#   inflating: dataset/with_mask/203-with-mask.jpg
#   inflating: dataset/with_mask/358-with-mask.jpg
#   inflating: dataset/with_mask/222-with-mask.jpg
#   inflating: dataset/with_mask/432-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_272.jpg
#   inflating: dataset/with_mask/257-with-mask.jpg
#   inflating: dataset/without_mask/194.jpg
#   inflating: dataset/with_mask/augmented_image_108.jpg
#   inflating: dataset/without_mask/111.jpg
#   inflating: dataset/without_mask/augmented_image_258.jpg
#   inflating: dataset/without_mask/256.jpg
#   inflating: dataset/without_mask/176.jpg
#   inflating: dataset/with_mask/429-with-mask.jpg
#   inflating: dataset/with_mask/448-with-mask.jpg
#   inflating: dataset/with_mask/355-with-mask.jpg
#   inflating: dataset/without_mask/207.jpg
#   inflating: dataset/without_mask/augmented_image_174.jpg
#   inflating: dataset/without_mask/402.jpg
#   inflating: dataset/without_mask/161.jpg
#   inflating: dataset/without_mask/augmented_image_241.jpg
#   inflating: dataset/with_mask/377-with-mask.jpg
#   inflating: dataset/with_mask/17-with-mask.jpg
#   inflating: dataset/with_mask/332-with-mask.jpg
#   inflating: dataset/with_mask/262-with-mask.jpg
#   inflating: dataset/with_mask/124-with-mask.jpg
#   inflating: dataset/with_mask/151-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_135.jpg
#   inflating: dataset/with_mask/augmented_image_145.jpg
#   inflating: dataset/with_mask/augmented_image_240.jpg
#   inflating: dataset/with_mask/augmented_image_187.jpg
#   inflating: dataset/with_mask/76-with-mask.jpg
#   inflating: dataset/without_mask/456.jpg
#   inflating: dataset/without_mask/407.jpg
#   inflating: dataset/without_mask/augmented_image_303.jpg
#   inflating: dataset/without_mask/augmented_image_284.jpg
#   inflating: dataset/without_mask/410.jpg
#   inflating: dataset/without_mask/127.jpg
#   inflating: dataset/with_mask/augmented_image_124.jpg
#   inflating: dataset/with_mask/397-with-mask.jpg
#   inflating: dataset/with_mask/101-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_165.jpg
#   inflating: dataset/without_mask/3.jpg
#   inflating: dataset/with_mask/338-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_42.jpg
#   inflating: dataset/without_mask/130.jpg
#   inflating: dataset/without_mask/395.jpg
#   inflating: dataset/with_mask/296-with-mask.jpg
#   inflating: dataset/without_mask/421.jpg
#   inflating: dataset/with_mask/253-with-mask.jpg
#   inflating: dataset/without_mask/307.jpg
#   inflating: dataset/without_mask/394.jpg
#   inflating: dataset/with_mask/augmented_image_214.jpg
#   inflating: dataset/without_mask/augmented_image_120.jpg
#   inflating: dataset/without_mask/154.jpg
#   inflating: dataset/without_mask/301.jpg
#   inflating: dataset/with_mask/65-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_138.jpg
#   inflating: dataset/with_mask/augmented_image_189.jpg
#   inflating: dataset/with_mask/180-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_202.jpg
#   inflating: dataset/with_mask/augmented_image_141.jpg
#   inflating: dataset/with_mask/306-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_143.jpg
#   inflating: dataset/without_mask/augmented_image_219.jpg
#   inflating: dataset/without_mask/63.jpg
#   inflating: dataset/without_mask/412.jpg
#   inflating: dataset/with_mask/93-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_139.jpg
#   inflating: dataset/with_mask/455-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_220.jpg
#   inflating: dataset/with_mask/270-with-mask.jpg
#   inflating: dataset/with_mask/21-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_136.jpg
#   inflating: dataset/with_mask/275-with-mask.jpg
#   inflating: dataset/without_mask/329.jpg
#   inflating: dataset/with_mask/52-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_128.jpg
#   inflating: dataset/without_mask/262.jpg
#   inflating: dataset/with_mask/augmented_image_287.jpg
#   inflating: dataset/with_mask/198-with-mask.jpg
#   inflating: dataset/without_mask/280.jpg
#   inflating: dataset/without_mask/augmented_image_203.jpg
#   inflating: dataset/with_mask/78-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_136.jpg
#   inflating: dataset/with_mask/205-with-mask.jpg
#   inflating: dataset/with_mask/294-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_193.jpg
#   inflating: dataset/with_mask/26-with-mask.jpg
#   inflating: dataset/with_mask/33-with-mask.jpg
#   inflating: dataset/with_mask/293-with-mask.jpg
#   inflating: dataset/without_mask/122.jpg
#   inflating: dataset/without_mask/augmented_image_124.jpg
#   inflating: dataset/without_mask/augmented_image_281.jpg
#   inflating: dataset/with_mask/augmented_image_305.jpg
#   inflating: dataset/with_mask/79-with-mask.jpg
#   inflating: dataset/without_mask/123.jpg
#   inflating: dataset/with_mask/252-with-mask.jpg
#   inflating: dataset/without_mask/14.jpg
#   inflating: dataset/without_mask/augmented_image_25.jpg
#   inflating: dataset/with_mask/308-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_270.jpg
#   inflating: dataset/without_mask/augmented_image_273.jpg
#   inflating: dataset/without_mask/128.jpg
#   inflating: dataset/without_mask/451.jpg
#   inflating: dataset/without_mask/augmented_image_58.jpg
#   inflating: dataset/with_mask/301-with-mask.jpg
#   inflating: dataset/with_mask/314-with-mask.jpg
#   inflating: dataset/with_mask/96-with-mask.jpg
#   inflating: dataset/with_mask/172-with-mask.jpg
#   inflating: dataset/with_mask/146-with-mask.jpg
#   inflating: dataset/without_mask/98.jpg
#   inflating: dataset/with_mask/276-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_287.jpg
#   inflating: dataset/without_mask/augmented_image_67.jpg
#   inflating: dataset/with_mask/100-with-mask.jpg
#   inflating: dataset/without_mask/302.jpg
#   inflating: dataset/without_mask/195.jpg
#   inflating: dataset/with_mask/399-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_182.jpg
#   inflating: dataset/with_mask/augmented_image_120.jpg
#   inflating: dataset/without_mask/augmented_image_192.jpg
#   inflating: dataset/without_mask/0.jpg
#   inflating: dataset/without_mask/augmented_image_186.jpg
#   inflating: dataset/without_mask/155.jpg
#   inflating: dataset/without_mask/171.jpg
#   inflating: dataset/without_mask/61.jpg
#   inflating: dataset/without_mask/348.jpg
#   inflating: dataset/without_mask/350.jpg
#   inflating: dataset/without_mask/99.jpg
#   inflating: dataset/with_mask/augmented_image_230.jpg
#   inflating: dataset/without_mask/420.jpg
#   inflating: dataset/without_mask/augmented_image_211.jpg
#   inflating: dataset/without_mask/125.jpg
#   inflating: dataset/with_mask/augmented_image_213.jpg
#   inflating: dataset/with_mask/augmented_image_25.jpg
#   inflating: dataset/with_mask/318-with-mask.jpg
#   inflating: dataset/with_mask/357-with-mask.jpg
#   inflating: dataset/without_mask/370.jpg
#   inflating: dataset/with_mask/augmented_image_295.jpg
#   inflating: dataset/with_mask/48-with-mask.jpg
#   inflating: dataset/without_mask/241.jpg
#   inflating: dataset/with_mask/182-with-mask.jpg
#   inflating: dataset/without_mask/87.jpg
#   inflating: dataset/with_mask/augmented_image_215.jpg
#   inflating: dataset/without_mask/181.jpg
#   inflating: dataset/with_mask/augmented_image_137.jpg
#   inflating: dataset/without_mask/345.jpg
#   inflating: dataset/without_mask/augmented_image_148.jpg
#   inflating: dataset/without_mask/augmented_image_48.jpg
#   inflating: dataset/with_mask/156-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_32.jpg
#   inflating: dataset/without_mask/422.jpg
#   inflating: dataset/with_mask/303-with-mask.jpg
#   inflating: dataset/with_mask/382-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_112.jpg
#   inflating: dataset/with_mask/augmented_image_267.jpg
#   inflating: dataset/without_mask/110.jpg
#   inflating: dataset/without_mask/augmented_image_64.jpg
#   inflating: dataset/with_mask/139-with-mask.jpg
#   inflating: dataset/without_mask/173.jpg
#   inflating: dataset/with_mask/augmented_image_242.jpg
#   inflating: dataset/without_mask/327.jpg
#   inflating: dataset/with_mask/445-with-mask.jpg
#   inflating: dataset/with_mask/256-with-mask.jpg
#   inflating: dataset/without_mask/112.jpg
#   inflating: dataset/without_mask/151.jpg
#   inflating: dataset/with_mask/381-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_306.jpg
#   inflating: dataset/with_mask/augmented_image_200.jpg
#   inflating: dataset/without_mask/augmented_image_57.jpg
#   inflating: dataset/without_mask/augmented_image_37.jpg
#   inflating: dataset/without_mask/augmented_image_224.jpg
#   inflating: dataset/without_mask/augmented_image_168.jpg
#   inflating: dataset/without_mask/414.jpg
#   inflating: dataset/without_mask/384.jpg
#   inflating: dataset/with_mask/141-with-mask.jpg
#   inflating: dataset/with_mask/232-with-mask.jpg
#   inflating: dataset/with_mask/438-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_182.jpg
#   inflating: dataset/without_mask/augmented_image_256.jpg
#   inflating: dataset/with_mask/153-with-mask.jpg
#   inflating: dataset/with_mask/136-with-mask.jpg
#   inflating: dataset/with_mask/290-with-mask.jpg
#   inflating: dataset/without_mask/180.jpg
#   inflating: dataset/without_mask/383.jpg
#   inflating: dataset/with_mask/augmented_image_104.jpg
#   inflating: dataset/without_mask/391.jpg
#   inflating: dataset/without_mask/442.jpg
#   inflating: dataset/with_mask/augmented_image_109.jpg
#   inflating: dataset/without_mask/augmented_image_316.jpg
#   inflating: dataset/with_mask/augmented_image_146.jpg
#   inflating: dataset/without_mask/augmented_image_69.jpg
#   inflating: dataset/without_mask/augmented_image_2.jpg
#   inflating: dataset/with_mask/augmented_image_128.jpg
#   inflating: dataset/without_mask/426.jpg
#   inflating: dataset/without_mask/augmented_image_305.jpg
#   inflating: dataset/without_mask/231.jpg
#   inflating: dataset/with_mask/433-with-mask.jpg
#   inflating: dataset/without_mask/289.jpg
#   inflating: dataset/without_mask/augmented_image_157.jpg
#   inflating: dataset/with_mask/86-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_133.jpg
#   inflating: dataset/with_mask/augmented_image_28.jpg
#   inflating: dataset/without_mask/augmented_image_187.jpg
#   inflating: dataset/with_mask/augmented_image_273.jpg
#   inflating: dataset/with_mask/70-with-mask.jpg
#   inflating: dataset/with_mask/144-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_149.jpg
#   inflating: dataset/without_mask/augmented_image_118.jpg
#   inflating: dataset/without_mask/44.jpg
#   inflating: dataset/without_mask/466.jpg
#   inflating: dataset/without_mask/52.jpg
#   inflating: dataset/with_mask/246-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_299.jpg
#   inflating: dataset/without_mask/119.jpg
#   inflating: dataset/without_mask/464.jpg
#   inflating: dataset/with_mask/augmented_image_194.jpg
#   inflating: dataset/with_mask/254-with-mask.jpg
#   inflating: dataset/with_mask/190-with-mask.jpg
#   inflating: dataset/without_mask/425.jpg
#   inflating: dataset/without_mask/augmented_image_229.jpg
#   inflating: dataset/with_mask/106-with-mask.jpg
#   inflating: dataset/with_mask/206-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_235.jpg
#   inflating: dataset/without_mask/augmented_image_119.jpg
#   inflating: dataset/without_mask/427.jpg
#   inflating: dataset/without_mask/269.jpg
#   inflating: dataset/with_mask/219-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_222.jpg
#   inflating: dataset/with_mask/441-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_198.jpg
#   inflating: dataset/with_mask/4-with-mask.jpg
#   inflating: dataset/without_mask/124.jpg
#   inflating: dataset/with_mask/446-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_100.jpg
#   inflating: dataset/without_mask/293.jpg
#   inflating: dataset/without_mask/augmented_image_16.jpg
#   inflating: dataset/with_mask/167-with-mask.jpg
#   inflating: dataset/without_mask/443.jpg
#   inflating: dataset/with_mask/304-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_298.jpg
#   inflating: dataset/without_mask/187.jpg
#   inflating: dataset/without_mask/augmented_image_237.jpg
#   inflating: dataset/without_mask/120.jpg
#   inflating: dataset/without_mask/306.jpg
#   inflating: dataset/with_mask/103-with-mask.jpg
#   inflating: dataset/without_mask/95.jpg
#   inflating: dataset/with_mask/augmented_image_147.jpg
#   inflating: dataset/without_mask/augmented_image_234.jpg
#   inflating: dataset/without_mask/419.jpg
#   inflating: dataset/with_mask/140-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_23.jpg
#   inflating: dataset/with_mask/444-with-mask.jpg
#   inflating: dataset/with_mask/43-with-mask.jpg
#   inflating: dataset/with_mask/436-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_256.jpg
#   inflating: dataset/with_mask/augmented_image_107.jpg
#   inflating: dataset/without_mask/349.jpg
#   inflating: dataset/with_mask/200-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_45.jpg
#   inflating: dataset/without_mask/augmented_image_245.jpg
#   inflating: dataset/without_mask/6.jpg
#   inflating: dataset/with_mask/185-with-mask.jpg
#   inflating: dataset/without_mask/285.jpg
#   inflating: dataset/without_mask/148.jpg
#   inflating: dataset/with_mask/347-with-mask.jpg
#   inflating: dataset/with_mask/114-with-mask.jpg
#   inflating: dataset/without_mask/70.jpg
#   inflating: dataset/with_mask/augmented_image_192.jpg
#   inflating: dataset/with_mask/5-with-mask.jpg
#   inflating: dataset/without_mask/91.jpg
#   inflating: dataset/without_mask/453.jpg
#   inflating: dataset/without_mask/augmented_image_210.jpg
#   inflating: dataset/with_mask/77-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_154.jpg
#   inflating: dataset/without_mask/387.jpg
#   inflating: dataset/with_mask/augmented_image_117.jpg
#   inflating: dataset/without_mask/392.jpg
#   inflating: dataset/with_mask/augmented_image_190.jpg
#   inflating: dataset/with_mask/259-with-mask.jpg
#   inflating: dataset/without_mask/311.jpg
#   inflating: dataset/with_mask/110-with-mask.jpg
#   inflating: dataset/without_mask/244.jpg
#   inflating: dataset/without_mask/281.jpg
#   inflating: dataset/with_mask/279-with-mask.jpg
#   inflating: dataset/with_mask/461-with-mask.jpg
#   inflating: dataset/with_mask/45-with-mask.jpg
#   inflating: dataset/with_mask/29-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_191.jpg
#   inflating: dataset/with_mask/augmented_image_123.jpg
#   inflating: dataset/with_mask/447-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_220.jpg
#   inflating: dataset/with_mask/augmented_image_138.jpg
#   inflating: dataset/with_mask/408-with-mask.jpg
#   inflating: dataset/with_mask/7-with-mask.jpg
#   inflating: dataset/without_mask/39.jpg
#   inflating: dataset/with_mask/augmented_image_13.jpg
#   inflating: dataset/with_mask/augmented_image_130.jpg
#   inflating: dataset/with_mask/234-with-mask.jpg
#   inflating: dataset/without_mask/437.jpg
#   inflating: dataset/without_mask/184.jpg
#   inflating: dataset/without_mask/28.jpg
#   inflating: dataset/with_mask/46-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_63.jpg
#   inflating: dataset/without_mask/augmented_image_310.jpg
#   inflating: dataset/without_mask/augmented_image_293.jpg
#   inflating: dataset/with_mask/62-with-mask.jpg
#   inflating: dataset/without_mask/179.jpg
#   inflating: dataset/with_mask/augmented_image_164.jpg
#   inflating: dataset/with_mask/364-with-mask.jpg
#   inflating: dataset/without_mask/454.jpg
#   inflating: dataset/without_mask/213.jpg
#   inflating: dataset/without_mask/augmented_image_126.jpg
#   inflating: dataset/without_mask/331.jpg
#   inflating: dataset/with_mask/282-with-mask.jpg
#   inflating: dataset/without_mask/462.jpg
#   inflating: dataset/without_mask/74.jpg
#   inflating: dataset/without_mask/augmented_image_39.jpg
#   inflating: dataset/without_mask/259.jpg
#   inflating: dataset/with_mask/174-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_246.jpg
#   inflating: dataset/with_mask/112-with-mask.jpg
#   inflating: dataset/with_mask/187-with-mask.jpg
#   inflating: dataset/without_mask/214.jpg
#   inflating: dataset/without_mask/355.jpg
#   inflating: dataset/with_mask/36-with-mask.jpg
#   inflating: dataset/with_mask/287-with-mask.jpg
#   inflating: dataset/with_mask/277-with-mask.jpg
#   inflating: dataset/without_mask/80.jpg
#   inflating: dataset/with_mask/augmented_image_140.jpg
#   inflating: dataset/with_mask/181-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_125.jpg
#   inflating: dataset/with_mask/391-with-mask.jpg
#   inflating: dataset/without_mask/389.jpg
#   inflating: dataset/without_mask/augmented_image_199.jpg
#   inflating: dataset/without_mask/266.jpg
#   inflating: dataset/without_mask/385.jpg
#   inflating: dataset/without_mask/290.jpg
#   inflating: dataset/without_mask/168.jpg
#   inflating: dataset/without_mask/4.jpg
#   inflating: dataset/without_mask/augmented_image_23.jpg
#   inflating: dataset/with_mask/augmented_image_195.jpg
#   inflating: dataset/without_mask/475.jpg
#   inflating: dataset/without_mask/augmented_image_53.jpg
#   inflating: dataset/without_mask/augmented_image_254.jpg
#   inflating: dataset/with_mask/augmented_image_144.jpg
#   inflating: dataset/without_mask/309.jpg
#   inflating: dataset/with_mask/316-with-mask.jpg
#   inflating: dataset/without_mask/255.jpg
#   inflating: dataset/with_mask/augmented_image_247.jpg
#   inflating: dataset/with_mask/424-with-mask.jpg
#   inflating: dataset/with_mask/32-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_257.jpg
#   inflating: dataset/with_mask/augmented_image_289.jpg
#   inflating: dataset/without_mask/286.jpg
#   inflating: dataset/with_mask/386-with-mask.jpg
#   inflating: dataset/without_mask/347.jpg
#   inflating: dataset/with_mask/14-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_222.jpg
#   inflating: dataset/without_mask/455.jpg
#   inflating: dataset/without_mask/64.jpg
#   inflating: dataset/with_mask/245-with-mask.jpg
#   inflating: dataset/with_mask/41-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_239.jpg
#   inflating: dataset/with_mask/217-with-mask.jpg
#   inflating: dataset/without_mask/374.jpg
#   inflating: dataset/without_mask/321.jpg
#   inflating: dataset/with_mask/291-with-mask.jpg
#   inflating: dataset/with_mask/451-with-mask.jpg
#   inflating: dataset/with_mask/214-with-mask.jpg
#   inflating: dataset/without_mask/97.jpg
#   inflating: dataset/without_mask/augmented_image_201.jpg
#   inflating: dataset/without_mask/augmented_image_263.jpg
#   inflating: dataset/without_mask/365.jpg
#   inflating: dataset/with_mask/augmented_image_171.jpg
#   inflating: dataset/with_mask/augmented_image_12.jpg
#   inflating: dataset/with_mask/augmented_image_148.jpg
#   inflating: dataset/with_mask/augmented_image_162.jpg
#   inflating: dataset/without_mask/344.jpg
#   inflating: dataset/with_mask/augmented_image_111.jpg
#   inflating: dataset/with_mask/105-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_211.jpg
#   inflating: dataset/without_mask/51.jpg
#   inflating: dataset/without_mask/298.jpg
#   inflating: dataset/without_mask/142.jpg
#   inflating: dataset/with_mask/augmented_image_207.jpg
#   inflating: dataset/without_mask/465.jpg
#   inflating: dataset/with_mask/augmented_image_277.jpg
#   inflating: dataset/without_mask/166.jpg
#   inflating: dataset/with_mask/255-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_199.jpg
#   inflating: dataset/without_mask/37.jpg
#   inflating: dataset/with_mask/233-with-mask.jpg
#   inflating: dataset/without_mask/401.jpg
#   inflating: dataset/without_mask/augmented_image_172.jpg
#   inflating: dataset/without_mask/94.jpg
#   inflating: dataset/without_mask/229.jpg
#   inflating: dataset/without_mask/318.jpg
#   inflating: dataset/without_mask/augmented_image_109.jpg
#   inflating: dataset/with_mask/319-with-mask.jpg
#   inflating: dataset/with_mask/235-with-mask.jpg
#   inflating: dataset/with_mask/322-with-mask.jpg
#   inflating: dataset/with_mask/3-with-mask.jpg
#   inflating: dataset/with_mask/81-with-mask.jpg
#   inflating: dataset/with_mask/313-with-mask.jpg
#   inflating: dataset/without_mask/76.jpg
#   inflating: dataset/with_mask/117-with-mask.jpg
#   inflating: dataset/with_mask/473-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_115.jpg
#   inflating: dataset/without_mask/augmented_image_318.jpg
#   inflating: dataset/with_mask/351-with-mask.jpg
#   inflating: dataset/with_mask/175-with-mask.jpg
#   inflating: dataset/without_mask/146.jpg
#   inflating: dataset/without_mask/89.jpg
#   inflating: dataset/without_mask/augmented_image_312.jpg
#   inflating: dataset/with_mask/107-with-mask.jpg
#   inflating: dataset/with_mask/422-with-mask.jpg
#   inflating: dataset/without_mask/100.jpg
#   inflating: dataset/with_mask/125-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_235.jpg
#   inflating: dataset/with_mask/123-with-mask.jpg
#   inflating: dataset/without_mask/265.jpg
#   inflating: dataset/with_mask/380-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_150.jpg
#   inflating: dataset/without_mask/augmented_image_177.jpg
#   inflating: dataset/without_mask/203.jpg
#   inflating: dataset/without_mask/424.jpg
#   inflating: dataset/without_mask/augmented_image_221.jpg
#   inflating: dataset/with_mask/99-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_203.jpg
#   inflating: dataset/without_mask/270.jpg
#   inflating: dataset/without_mask/augmented_image_262.jpg
# ...
#   inflating: dataset/without_mask/430.jpg
#   inflating: dataset/without_mask/augmented_image_144.jpg
#   inflating: dataset/without_mask/378.jpg
#   inflating: dataset/without_mask/24.jpg
#   inflating: dataset/with_mask/289-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_314.jpg
#   inflating: dataset/without_mask/211.jpg
#   inflating: dataset/with_mask/192-with-mask.jpg
#   inflating: dataset/with_mask/23-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_243.jpg
#   inflating: dataset/without_mask/459.jpg
#   inflating: dataset/with_mask/285-with-mask.jpg
#   inflating: dataset/without_mask/140.jpg
#   inflating: dataset/without_mask/7.jpg
#   inflating: dataset/with_mask/augmented_image_105.jpg
#   inflating: dataset/without_mask/447.jpg
#   inflating: dataset/with_mask/augmented_image_132.jpg
#   inflating: dataset/without_mask/325.jpg
#   inflating: dataset/with_mask/333-with-mask.jpg
#   inflating: dataset/with_mask/375-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_22.jpg
#   inflating: dataset/with_mask/201-with-mask.jpg
#   inflating: dataset/without_mask/303.jpg
#   inflating: dataset/without_mask/augmented_image_50.jpg
#   inflating: dataset/with_mask/472-with-mask.jpg
#   inflating: dataset/without_mask/108.jpg
#   inflating: dataset/with_mask/116-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_159.jpg
#   inflating: dataset/without_mask/156.jpg
#   inflating: dataset/without_mask/augmented_image_116.jpg
#   inflating: dataset/with_mask/18-with-mask.jpg
#   inflating: dataset/without_mask/135.jpg
#   inflating: dataset/with_mask/170-with-mask.jpg
#   inflating: dataset/with_mask/15-with-mask.jpg
#   inflating: dataset/with_mask/272-with-mask.jpg
#   inflating: dataset/without_mask/388.jpg
#   inflating: dataset/without_mask/13.jpg
#   inflating: dataset/without_mask/augmented_image_65.jpg
#   inflating: dataset/without_mask/139.jpg
#   inflating: dataset/with_mask/163-with-mask.jpg
#   inflating: dataset/with_mask/10-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_258.jpg
#   inflating: dataset/without_mask/323.jpg
#   inflating: dataset/without_mask/augmented_image_13.jpg
#   inflating: dataset/without_mask/423.jpg
#   inflating: dataset/with_mask/augmented_image_18.jpg
#   inflating: dataset/with_mask/189-with-mask.jpg
#   inflating: dataset/with_mask/147-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_110.jpg
#   inflating: dataset/without_mask/223.jpg
#   inflating: dataset/without_mask/58.jpg
#   inflating: dataset/with_mask/456-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_302.jpg
#   inflating: dataset/with_mask/169-with-mask.jpg
#   inflating: dataset/with_mask/218-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_122.jpg
#   inflating: dataset/with_mask/335-with-mask.jpg
#   inflating: dataset/without_mask/317.jpg
#   inflating: dataset/with_mask/476-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_251.jpg
#   inflating: dataset/with_mask/82-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_62.jpg
#   inflating: dataset/without_mask/399.jpg
#   inflating: dataset/with_mask/augmented_image_186.jpg
#   inflating: dataset/without_mask/397.jpg
#   inflating: dataset/with_mask/augmented_image_245.jpg
#   inflating: dataset/with_mask/395-with-mask.jpg
#   inflating: dataset/without_mask/461.jpg
#   inflating: dataset/without_mask/augmented_image_315.jpg
#   inflating: dataset/without_mask/261.jpg
#   inflating: dataset/without_mask/augmented_image_155.jpg
#   inflating: dataset/with_mask/augmented_image_300.jpg
#   inflating: dataset/without_mask/augmented_image_131.jpg
#   inflating: dataset/without_mask/augmented_image_296.jpg
#   inflating: dataset/without_mask/212.jpg
#   inflating: dataset/with_mask/augmented_image_21.jpg
#   inflating: dataset/with_mask/augmented_image_119.jpg
#   inflating: dataset/with_mask/68-with-mask.jpg
#   inflating: dataset/with_mask/459-with-mask.jpg
#   inflating: dataset/with_mask/72-with-mask.jpg
#   inflating: dataset/without_mask/66.jpg
#   inflating: dataset/without_mask/augmented_image_35.jpg
#   inflating: dataset/with_mask/160-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_30.jpg
#   inflating: dataset/with_mask/336-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_231.jpg
#   inflating: dataset/with_mask/419-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_166.jpg
#   inflating: dataset/without_mask/101.jpg
#   inflating: dataset/without_mask/226.jpg
#   inflating: dataset/without_mask/augmented_image_240.jpg
#   inflating: dataset/with_mask/augmented_image_161.jpg
#   inflating: dataset/with_mask/34-with-mask.jpg
#   inflating: dataset/with_mask/137-with-mask.jpg
#   inflating: dataset/with_mask/30-with-mask.jpg
#   inflating: dataset/with_mask/204-with-mask.jpg
#   inflating: dataset/without_mask/376.jpg
#   inflating: dataset/without_mask/augmented_image_278.jpg
#   inflating: dataset/with_mask/augmented_image_261.jpg
#   inflating: dataset/with_mask/39-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_299.jpg
#   inflating: dataset/without_mask/251.jpg
#   inflating: dataset/without_mask/19.jpg
#   inflating: dataset/without_mask/22.jpg
#   inflating: dataset/with_mask/121-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_206.jpg
#   inflating: dataset/without_mask/326.jpg
#   inflating: dataset/without_mask/230.jpg
#   inflating: dataset/without_mask/augmented_image_275.jpg
#   inflating: dataset/with_mask/augmented_image_228.jpg
#   inflating: dataset/with_mask/196-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_208.jpg
#   inflating: dataset/with_mask/augmented_image_179.jpg
#   inflating: dataset/with_mask/317-with-mask.jpg
#   inflating: dataset/without_mask/440.jpg
#   inflating: dataset/with_mask/augmented_image_209.jpg
#   inflating: dataset/with_mask/414-with-mask.jpg
#   inflating: dataset/without_mask/15.jpg
#   inflating: dataset/with_mask/71-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_103.jpg
#   inflating: dataset/without_mask/224.jpg
#   inflating: dataset/without_mask/480.jpg
#   inflating: dataset/without_mask/augmented_image_44.jpg
#   inflating: dataset/with_mask/augmented_image_158.jpg
#   inflating: dataset/with_mask/221-with-mask.jpg
#   inflating: dataset/without_mask/1.jpg
#   inflating: dataset/with_mask/478-with-mask.jpg
#   inflating: dataset/with_mask/251-with-mask.jpg
#   inflating: dataset/without_mask/242.jpg
#   inflating: dataset/without_mask/460.jpg
#   inflating: dataset/with_mask/109-with-mask.jpg
#   inflating: dataset/with_mask/281-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_2.jpg
#   inflating: dataset/with_mask/193-with-mask.jpg
#   inflating: dataset/without_mask/234.jpg
#   inflating: dataset/without_mask/228.jpg
#   inflating: dataset/with_mask/238-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_3.jpg
#   inflating: dataset/without_mask/46.jpg
#   inflating: dataset/without_mask/340.jpg
#   inflating: dataset/with_mask/augmented_image_127.jpg
#   inflating: dataset/with_mask/augmented_image_26.jpg
#   inflating: dataset/without_mask/107.jpg
#   inflating: dataset/without_mask/458.jpg
#   inflating: dataset/with_mask/augmented_image_234.jpg
#   inflating: dataset/with_mask/8-with-mask.jpg
#   inflating: dataset/without_mask/398.jpg
#   inflating: dataset/with_mask/385-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_304.jpg
#   inflating: dataset/with_mask/471-with-mask.jpg
#   inflating: dataset/with_mask/411-with-mask.jpg
#   inflating: dataset/without_mask/204.jpg
#   inflating: dataset/without_mask/augmented_image_308.jpg
#   inflating: dataset/without_mask/augmented_image_283.jpg
#   inflating: dataset/with_mask/462-with-mask.jpg
#   inflating: dataset/without_mask/409.jpg
#   inflating: dataset/without_mask/169.jpg
#   inflating: dataset/without_mask/augmented_image_160.jpg
#   inflating: dataset/without_mask/augmented_image_290.jpg
#   inflating: dataset/without_mask/191.jpg
#   inflating: dataset/with_mask/augmented_image_252.jpg
#   inflating: dataset/with_mask/176-with-mask.jpg
#   inflating: dataset/without_mask/450.jpg
#   inflating: dataset/without_mask/augmented_image_227.jpg
#   inflating: dataset/with_mask/augmented_image_102.jpg
#   inflating: dataset/with_mask/37-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_180.jpg
#   inflating: dataset/without_mask/augmented_image_133.jpg
#   inflating: dataset/without_mask/172.jpg
#   inflating: dataset/without_mask/augmented_image_183.jpg
#   inflating: dataset/with_mask/171-with-mask.jpg
#   inflating: dataset/with_mask/425-with-mask.jpg
#   inflating: dataset/without_mask/413.jpg
#   inflating: dataset/with_mask/augmented_image_27.jpg
#   inflating: dataset/with_mask/481-with-mask.jpg
#   inflating: dataset/with_mask/75-with-mask.jpg
#   inflating: dataset/without_mask/403.jpg
#   inflating: dataset/without_mask/48.jpg
#   inflating: dataset/without_mask/12.jpg
#   inflating: dataset/without_mask/27.jpg
#   inflating: dataset/without_mask/116.jpg
#   inflating: dataset/without_mask/34.jpg
#   inflating: dataset/without_mask/297.jpg
#   inflating: dataset/with_mask/342-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_251.jpg
#   inflating: dataset/with_mask/augmented_image_169.jpg
#   inflating: dataset/with_mask/268-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_286.jpg
#   inflating: dataset/without_mask/42.jpg
#   inflating: dataset/with_mask/236-with-mask.jpg
#   inflating: dataset/without_mask/215.jpg
#   inflating: dataset/without_mask/30.jpg
#   inflating: dataset/without_mask/augmented_image_161.jpg
#   inflating: dataset/without_mask/augmented_image_31.jpg
#   inflating: dataset/without_mask/118.jpg
#   inflating: dataset/with_mask/augmented_image_16.jpg
#   inflating: dataset/without_mask/augmented_image_134.jpg
#   inflating: dataset/without_mask/augmented_image_260.jpg
#   inflating: dataset/with_mask/127-with-mask.jpg
#   inflating: dataset/with_mask/362-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_277.jpg
#   inflating: dataset/with_mask/229-with-mask.jpg
#   inflating: dataset/without_mask/177.jpg
#   inflating: dataset/with_mask/286-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_115.jpg
#   inflating: dataset/with_mask/augmented_image_152.jpg
#   inflating: dataset/without_mask/16.jpg
#   inflating: dataset/with_mask/89-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_174.jpg
#   inflating: dataset/without_mask/375.jpg
#   inflating: dataset/without_mask/65.jpg
#   inflating: dataset/with_mask/379-with-mask.jpg
#   inflating: dataset/with_mask/426-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_122.jpg
#   inflating: dataset/without_mask/augmented_image_191.jpg
#   inflating: dataset/without_mask/312.jpg
#   inflating: dataset/with_mask/augmented_image_218.jpg
#   inflating: dataset/with_mask/431-with-mask.jpg
#   inflating: dataset/with_mask/155-with-mask.jpg
#   inflating: dataset/without_mask/452.jpg
#   inflating: dataset/without_mask/310.jpg
#   inflating: dataset/without_mask/augmented_image_129.jpg
#   inflating: dataset/with_mask/297-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_207.jpg
#   inflating: dataset/without_mask/augmented_image_194.jpg
#   inflating: dataset/with_mask/298-with-mask.jpg
#   inflating: dataset/without_mask/50.jpg
#   inflating: dataset/without_mask/222.jpg
#   inflating: dataset/with_mask/474-with-mask.jpg
#   inflating: dataset/with_mask/131-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_156.jpg
#   inflating: dataset/without_mask/356.jpg
#   inflating: dataset/without_mask/284.jpg
#   inflating: dataset/without_mask/augmented_image_141.jpg
#   inflating: dataset/without_mask/augmented_image_252.jpg
#   inflating: dataset/with_mask/466-with-mask.jpg
#   inflating: dataset/without_mask/243.jpg
#   inflating: dataset/without_mask/237.jpg
#   inflating: dataset/with_mask/108-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_202.jpg
#   inflating: dataset/without_mask/augmented_image_107.jpg
#   inflating: dataset/without_mask/79.jpg
#   inflating: dataset/without_mask/334.jpg
#   inflating: dataset/with_mask/184-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_153.jpg
#   inflating: dataset/without_mask/augmented_image_169.jpg
#   inflating: dataset/with_mask/356-with-mask.jpg
#   inflating: dataset/with_mask/85-with-mask.jpg
#   inflating: dataset/without_mask/218.jpg
#   inflating: dataset/without_mask/augmented_image_113.jpg
#   inflating: dataset/with_mask/334-with-mask.jpg
#   inflating: dataset/with_mask/159-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_173.jpg
#   inflating: dataset/with_mask/404-with-mask.jpg
#   inflating: dataset/without_mask/136.jpg
#   inflating: dataset/without_mask/476.jpg
#   inflating: dataset/with_mask/243-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_74.jpg
#   inflating: dataset/without_mask/415.jpg
#   inflating: dataset/with_mask/augmented_image_184.jpg
#   inflating: dataset/with_mask/260-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_236.jpg
#   inflating: dataset/without_mask/435.jpg
#   inflating: dataset/with_mask/209-with-mask.jpg
#   inflating: dataset/with_mask/53-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_254.jpg
#   inflating: dataset/with_mask/368-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_60.jpg
#   inflating: dataset/without_mask/augmented_image_56.jpg
#   inflating: dataset/without_mask/augmented_image_68.jpg
#   inflating: dataset/without_mask/18.jpg
#   inflating: dataset/with_mask/467-with-mask.jpg
#   inflating: dataset/with_mask/197-with-mask.jpg
#   inflating: dataset/without_mask/augmented_image_205.jpg
#   inflating: dataset/with_mask/324-with-mask.jpg
#   inflating: dataset/without_mask/386.jpg
#   inflating: dataset/with_mask/augmented_image_131.jpg
#   inflating: dataset/with_mask/84-with-mask.jpg
#   inflating: dataset/with_mask/177-with-mask.jpg
#   inflating: dataset/with_mask/227-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_32.jpg
#   inflating: dataset/without_mask/275.jpg
#   inflating: dataset/without_mask/319.jpg
#   inflating: dataset/without_mask/164.jpg
#   inflating: dataset/without_mask/220.jpg
#   inflating: dataset/with_mask/augmented_image_201.jpg
#   inflating: dataset/without_mask/92.jpg
#   inflating: dataset/without_mask/149.jpg
#   inflating: dataset/with_mask/401-with-mask.jpg
#   inflating: dataset/without_mask/364.jpg
#   inflating: dataset/with_mask/152-with-mask.jpg
#   inflating: dataset/without_mask/337.jpg
#   inflating: dataset/with_mask/194-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_210.jpg
#   inflating: dataset/with_mask/244-with-mask.jpg
#   inflating: dataset/with_mask/98-with-mask.jpg
#   inflating: dataset/with_mask/38-with-mask.jpg
#   inflating: dataset/with_mask/augmented_image_142.jpg
#   inflating: dataset/without_mask/288.jpg
#   inflating: dataset/without_mask/augmented_image_114.jpg
#   inflating: dataset/with_mask/307-with-mask.jpg
#   inflating: dataset/with_mask/133-with-mask.jpg
#   inflating: dataset/without_mask/23.jpg
#   inflating: dataset/without_mask/augmented_image_309.jpg
#   inflating: dataset/with_mask/231-with-mask.jpg
#   inflating: dataset/without_mask/196.jpg
#   inflating: dataset/without_mask/augmented_image_132.jpg
#   inflating: dataset/without_mask/augmented_image_249.jpg
#   inflating: dataset/without_mask/263.jpg
#   inflating: dataset/with_mask/11-with-mask.jpg
#   inflating: dataset/without_mask/47.jpg
#   inflating: dataset/with_mask/augmented_image_139.jpg
#   inflating: dataset/without_mask/augmented_image_54.jpg

# %% [markdown]
# ## **Importing Libraries**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import os

# %% [markdown]
# ## **Preparing Data**

# %%
imagePaths = list(paths.list_images("/content/dataset"))
len(imagePaths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eb27149c7af3> in <module>()
# ----> 1 imagePaths = list(paths.list_images("/content/dataset"))
#       2 len(imagePaths)
#
# NameError: name 'paths' is not defined

# %%
### Data processing can also be done as follows.
'''import cv2
X_data =[]
for file in imagePaths:
    face = cv2.imread(file,cv2.IMREAD_COLOR)
    face = cv2.resize(face, (224,224) )
    X_data.append(face)
X_data=np.array(X_data)
X_data = X_data.astype('float32')
X_data /= 255
X_data[1]'''
# Out:
# "import cv2\nX_data =[]\nfor file in imagePaths:\n    face = cv2.imread(file,cv2.IMREAD_COLOR)\n    face = cv2.resize(face, (224,224) )\n    X_data.append(face)\nX_data=np.array(X_data)\nX_data = X_data.astype('float32')\nX_data /= 255\nX_data[1]"

# %%
data = []
labels = []
for imagePath in imagePaths:
  label = imagePath.split(os.path.sep)[-2]  #-2 means you are fetching the 2nd value after separating the path from the end
  image = image = load_img(imagePath, target_size=(224, 224))
  image = img_to_array(image)
  image = preprocess_input(image)
  data.append(image)
  labels.append(label)

data = np.array(data, dtype="float32")
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4cd405bfdda6> in <module>()
#       1 data = []
#       2 labels = []
# ----> 3 for imagePath in imagePaths:
#       4   label = imagePath.split(os.path.sep)[-2]  #-2 means you are fetching the 2nd value after separating the path from the end
#       5   image = image = load_img(imagePath, target_size=(224, 224))
#
# NameError: name 'imagePaths' is not defined

# %%
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = np.array(labels)
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %% [markdown]
# ## **Training data**

# %%
# partition the data into training and testing splits using 75% of the data for training and the remaining 25% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

# %%
aug = ImageDataGenerator(
	rotation_range=20,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest")

# %% [markdown]
# ## **Model Architecture**

# %%
# load the MobileNetV2 network, ensuring the head FC layer sets are left off
baseModel = MobileNetV2(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(224, 224, 3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step

# %%
# construct the head of the model that will be placed on top of the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# %%
model = Model(inputs=baseModel.input, outputs=headModel)

# %%
# loop over all layers in the base model and freeze them so they will *not* be updated during the first training process
for layer in baseModel.layers:
	layer.trainable = False

# %% [markdown]
# ## **Training, Prediction and Evaluation of Model**

# %%
INIT_LR = 1e-4
EPOCHS = 20
BS = 32
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])

# %%
H = model.fit(
	aug.flow(trainX, trainY, batch_size=BS),
	steps_per_epoch=len(trainX) // BS,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BS,
	epochs=EPOCHS)
# Out:
# Epoch 1/20
# 34/34 [==============================] - 12s 339ms/step - loss: 0.6827 - accuracy: 0.6891 - val_loss: 0.1550 - val_accuracy: 0.9601
# Epoch 2/20
# 34/34 [==============================] - 11s 316ms/step - loss: 0.1733 - accuracy: 0.9457 - val_loss: 0.0670 - val_accuracy: 0.9855
# Epoch 3/20
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0917 - accuracy: 0.9672 - val_loss: 0.0431 - val_accuracy: 0.9891
# Epoch 4/20
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0688 - accuracy: 0.9803 - val_loss: 0.0293 - val_accuracy: 0.9964
# Epoch 5/20
# 34/34 [==============================] - 11s 309ms/step - loss: 0.0521 - accuracy: 0.9813 - val_loss: 0.0229 - val_accuracy: 0.9928
# Epoch 6/20
# 34/34 [==============================] - 11s 309ms/step - loss: 0.0431 - accuracy: 0.9869 - val_loss: 0.0179 - val_accuracy: 1.0000
# Epoch 7/20
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0363 - accuracy: 0.9925 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 8/20
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0287 - accuracy: 0.9888 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 9/20
# 34/34 [==============================] - 11s 317ms/step - loss: 0.0265 - accuracy: 0.9897 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 10/20
# 34/34 [==============================] - 11s 317ms/step - loss: 0.0341 - accuracy: 0.9906 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 11/20
# 34/34 [==============================] - 11s 318ms/step - loss: 0.0218 - accuracy: 0.9944 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 12/20
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0277 - accuracy: 0.9906 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 13/20
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 14/20
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0157 - accuracy: 0.9963 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 15/20
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0261 - accuracy: 0.9897 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 16/20
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0196 - accuracy: 0.9916 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 17/20
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 18/20
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 19/20
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0143 - accuracy: 0.9972 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 20/20
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0178 - accuracy: 0.9916 - val_loss: 0.0042 - val_accuracy: 1.0000

# %%
predIdxs = model.predict(testX, batch_size=BS)

# %%
predIdxs = np.argmax(predIdxs, axis=1)

# %%
print(classification_report(testY.argmax(axis=1), predIdxs,
	target_names=lb.classes_))
# Out:
#               precision    recall  f1-score   support
#
#    with_mask       1.00      1.00      1.00       138
# without_mask       1.00      1.00      1.00       138
#
#     accuracy                           1.00       276
#    macro avg       1.00      1.00      1.00       276
# weighted avg       1.00      1.00      1.00       276

# %% [markdown]
# ## **Visualization and Saving Model**

# %%
model.save("MaskModel.h5")

# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot")

# %% [markdown]
# ## **Detecting from Image**

# %%
#uploading image
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd1e874b-6fe6-4608-a47a-fdead6bda940" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd1e874b-6fe6-4608-a47a-fdead6bda940">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving example_01.png to example_01.png

# %%
import cv2
from tensorflow.keras.models import load_model
net = cv2.dnn.readNet("/content/deploy.prototxt", "/content/res10_300x300_ssd_iter_140000.caffemodel")
model = load_model('/content/MaskModel.h5')

# load the input image from disk, clone it, and grab the image spatial
# dimensions
image = cv2.imread("example_01.png")
orig = image.copy()
(h, w) = image.shape[:2]

# construct a blob from the image
blob = cv2.dnn.blobFromImage(image, 1.0, (300, 300),
	(104.0, 177.0, 123.0))

net.setInput(blob)
detections = net.forward()

# loop over the detections
for i in range(0, detections.shape[2]):
  confidence = detections[0, 0, i, 2]
  if confidence > 0.5:
    # compute the (x, y)-coordinates of the bounding box
    box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
    (startX, startY, endX, endY) = box.astype("int")
    (startX, startY) = (max(0, startX), max(0, startY))
    (endX, endY) = (min(w - 1, endX), min(h - 1, endY))
    face = image[startY:endY, startX:endX]
    face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
    face = cv2.resize(face, (224, 224))
    face = img_to_array(face)
    face = preprocess_input(face)
    face = np.expand_dims(face, axis=0)

		# pass the face through the model to determine if the face
		# has a mask or not
    (mask, withoutMask) = model.predict(face)[0]

		# determine the class label and color we'll use to draw
		# the bounding box and text
    label = "Mask" if mask > withoutMask else "No Mask"
    color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

		# include the probability in the label
    label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

		# display the label and bounding box rectangle on the output
		# frame
    cv2.putText(image, label, (startX, startY - 10),
			cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
    cv2.rectangle(image, (startX, startY), (endX, endY), color, 2)

# show the output image
plt.imshow(image)
print(label)
# Out:
# Mask: 99.76%

# %% [markdown]
# ## **Detecting Realtime**

# %%
def detect_and_predict_mask(frame, faceNet, maskNet):
    # grab the dimensions of the frame and then construct a blob
    # from it
    (h, w) = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 1.0, (300, 300),
      (104.0, 177.0, 123.0))

    # pass the blob through the network and obtain the face detections
    faceNet.setInput(blob)
    detections = faceNet.forward()

    # initialize our list of faces, their corresponding locations,
    # and the list of predictions from our face mask network
    faces = []
    locs = []
    preds = []
    for i in range(0, detections.shape[2]):
      # extract the confidence (i.e., probability) associated with
      # the detection
      confidence = detections[0, 0, i, 2]
      if confidence > 0.5:
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        (startX, startY, endX, endY) = box.astype("int")

        # ensure the bounding boxes fall within the dimensions of
        # the frame
        (startX, startY) = (max(0, startX), max(0, startY))
        (endX, endY) = (min(w - 1, endX), min(h - 1, endY))

        # extract the face ROI, convert it from BGR to RGB channel
        # ordering, resize it to 224x224, and preprocess it
        face = frame[startY:endY, startX:endX]
        face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        face = cv2.resize(face, (224, 224))
        face = img_to_array(face)
        face = preprocess_input(face)

        # add the face and bounding boxes to their respective
        # lists
        faces.append(face)
        locs.append((startX, startY, endX, endY))

    # only make a predictions if at least one face was detected
    if len(faces) > 0:
      # for faster inference we'll make batch predictions on *all*
      # faces at the same time rather than one-by-one predictions
      # in the above `for` loop
      faces = np.array(faces, dtype="float32")
      preds = maskNet.predict(faces, batch_size=32)

    # return a 2-tuple of the face locations and their corresponding
    # locations
    return (locs, preds)

# %%
from imutils.video import VideoStream
import time
import imutils
faceNet = cv2.dnn.readNet("deploy.prototxt", "res10_300x300_ssd_iter_140000.caffemodel")

# load the face mask detector model from disk
maskNet = load_model('MaskModel.h5')

# initialize the video stream and allow the camera sensor to warm up
print("[INFO] starting video stream...")
vs = VideoStream(src=0).start()
time.sleep(2.0)

# loop over the frames from the video stream
while True:
	# grab the frame from the threaded video stream and resize it
	# to have a maximum width of 400 pixels
	frame = vs.read()
	frame = imutils.resize(frame, width=400)

	# detect faces in the frame and determine if they are wearing a
	# face mask or not
	(locs, preds) = detect_and_predict_mask(frame, faceNet, maskNet)

	# loop over the detected face locations and their corresponding
	# locations
	for (box, pred) in zip(locs, preds):
		# unpack the bounding box and predictions
		(startX, startY, endX, endY) = box
		(mask, withoutMask) = pred

		# determine the class label and color we'll use to draw
		# the bounding box and text
		label = "Mask" if mask > withoutMask else "No Mask"
		color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

		# include the probability in the label
		label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)

		# display the label and bounding box rectangle on the output
		# frame
		cv2.putText(frame, label, (startX, startY - 10),
			cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
		cv2.rectangle(frame, (startX, startY), (endX, endY), color, 2)

	# show the output frame
	cv2.imshow("Frame", frame)
	key = cv2.waitKey(1) & 0xFF

	# if the `q` key was pressed, break from the loop
	if key == ord("q"):
		break

# do a bit of cleanup
cv2.destroyAllWindows()
vs.stop()
